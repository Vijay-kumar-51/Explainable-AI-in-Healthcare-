# %%
import matplotlib.pyplot as plt

epochs = range(1, 26)

# EfficientNet
eff_train_acc = [0.6523,0.7896,0.8260,0.8458,0.8500,0.8581,0.8677,0.8738,0.8777,0.8773,
                 0.8848,0.8903,0.8929,0.8934,0.8971,0.9020,0.8931,0.9121,0.9167,0.9123,
                 0.9137,0.9121,0.9141,0.9160,0.9198]

eff_val_acc = [0.7496,0.7953,0.8151,0.8189,0.8272,0.8440,0.8326,0.8486,0.8356,0.8683,
               0.8486,0.8760,0.8828,0.8729,0.8737,0.8744,0.8790,0.8820,0.8843,0.8889,
               0.8927,0.9011,0.9026,0.8965,0.9049]

# ResNet50
res_train_acc = [0.6846,0.8164,0.8544,0.8668,0.8757,0.8885,0.8952,0.8960,0.9015,0.9060,
                 0.9170,0.9111,0.9123,0.9240,0.9223,0.9202,0.9267,0.9316,0.9284,0.9298,
                 0.9307,0.9342,0.9375,0.9391,0.9414]

res_val_acc = [0.8227,0.8478,0.8600,0.8653,0.8744,0.8820,0.8782,0.8836,0.8942,0.8980,
               0.9049,0.9026,0.9064,0.9148,0.9178,0.9132,0.9186,0.9087,0.9216,0.9231,
               0.9239,0.9239,0.9224,0.9247,0.9254]

# DenseNet121
den_train_acc = [0.5887,0.7728,0.8063,0.8278,0.8493,0.8497,0.8649,0.8672,0.8733,0.8862,
                 0.8854,0.8798,0.8876,0.8941,0.8903,0.8939,0.8976,0.8967,0.9013,0.9041,
                 0.9029,0.9097,0.9046,0.9130,0.9135]

den_val_acc = [0.7747,0.7953,0.8242,0.8250,0.8311,0.8333,0.8432,0.8409,0.8356,0.8554,
               0.8394,0.8630,0.8600,0.8623,0.8699,0.8714,0.8721,0.8729,0.8721,0.8775,
               0.8820,0.8752,0.8836,0.8881,0.8874]

# Accuracy Plot for All Models

plt.figure()
plt.scatter(epochs, eff_val_acc, label="EfficientNet")
plt.scatter(epochs, res_val_acc, label="ResNet50")
plt.scatter(epochs, den_val_acc, label="DenseNet121")
plt.plot(epochs, eff_val_acc)
plt.plot(epochs, res_val_acc)
plt.plot(epochs, den_val_acc)

plt.xlabel("Epochs")
plt.ylabel("Validation Accuracy")
plt.title("CNN-Models Comparison of Training Phase")
plt.legend()
plt.show()

# %%
epochs_ft = range(1, 6)

# EfficientNet
eff_ft_val = [0.8729,0.8721,0.8767,0.8782,0.8858]

# ResNet
res_ft_val = [0.9262,0.9368,0.9513,0.9536,0.9642]

# DenseNet
den_ft_val = [0.8798,0.8790,0.8760,0.8843,0.8858]

plt.figure()
plt.scatter(epochs_ft, eff_ft_val, label="EfficientNet")
plt.scatter(epochs_ft, res_ft_val, label="ResNet50")
plt.scatter(epochs_ft, den_ft_val, label="DenseNet121")

plt.plot(epochs_ft, eff_ft_val)
plt.plot(epochs_ft, res_ft_val)
plt.plot(epochs_ft, den_ft_val)

plt.xlabel("Epochs")
plt.ylabel("Validation Accuracy")
plt.title("Fine-Tuning Comparison of Validation Accuracy")
plt.legend()
plt.show()

# %%
epochs_ft = range(1, 6)

# EfficientNet
eff_ft_acc = [0.8334,0.8735,0.8873,0.8929,0.8992]

# ResNet
res_ft_acc = [0.9156,0.9368,0.9499,0.9599,0.9636]

# DenseNet
den_ft_acc = [0.8007,0.8820,0.8955,0.8973,0.9027]

plt.figure()
plt.scatter(epochs_ft, eff_ft_acc, label="EfficientNet")
plt.scatter(epochs_ft, res_ft_acc, label="ResNet50")
plt.scatter(epochs_ft, den_ft_acc, label="DenseNet121")
plt.plot(epochs_ft, eff_ft_acc)
plt.plot(epochs_ft, res_ft_acc)
plt.plot(epochs_ft, den_ft_acc)

plt.xlabel("Epochs")
plt.ylabel("Validation Accuracy")
plt.title("Fine-Tuning Comparison of Accuracy")
plt.legend()
plt.show()

# %%
models = ["EfficientNet", "ResNet50", "DenseNet121"]
final_acc = [0.9049, 0.9254, 0.8874]
fine_tuned_acc = [0.8858, 0.9642, 0.8858]

x = range(len(models))

plt.figure()
plt.bar(x, final_acc, width=0.2, label="Before FT")
plt.bar([i+0.2 for i in x], fine_tuned_acc, width=0.2, label="After FT")
plt.xticks([i+0.1 for i in x], models)
plt.xlabel("models")
plt.ylabel("Accuracy")
plt.title("Models Accuracy: Before vs After Fine-Tuning")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(1, 26)

# Accuracy
eff_train_acc = [0.6523,0.7896,0.8260,0.8458,0.8500,0.8581,0.8677,0.8738,0.8777,0.8773,
                 0.8848,0.8903,0.8929,0.8934,0.8971,0.9020,0.8931,0.9121,0.9167,0.9123,
                 0.9137,0.9121,0.9141,0.9160,0.9198]

eff_val_acc = [0.7496,0.7953,0.8151,0.8189,0.8272,0.8440,0.8326,0.8486,0.8356,0.8683,
               0.8486,0.8760,0.8828,0.8729,0.8737,0.8744,0.8790,0.8820,0.8843,0.8889,
               0.8927,0.9011,0.9026,0.8965,0.9049]

# Loss
eff_train_loss = [0.8877,0.5608,0.4853,0.4268,0.4114,0.3968,0.3768,0.3549,0.3403,0.3362,
                  0.3191,0.3072,0.3071,0.2935,0.2905,0.2752,0.2822,0.2591,0.2550,0.2539,
                  0.2376,0.2443,0.2435,0.2367,0.2269]

eff_val_loss = [0.6274,0.5205,0.4884,0.4486,0.4210,0.4014,0.4060,0.3645,0.3826,0.3334,
                0.3592,0.3114,0.3083,0.3042,0.2969,0.2918,0.2845,0.2940,0.2872,0.2717,
                0.2678,0.2562,0.2548,0.2524,0.2369]

# Accuracy Graph
plt.figure()
plt.scatter(epochs, eff_train_acc, label="Train Accuracy")
plt.scatter(epochs, eff_val_acc, label="Validation Accuracy")
plt.plot(epochs, eff_train_acc)
plt.plot(epochs, eff_val_acc)
plt.title("EfficientNetB0 Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Loss Graph
plt.figure()
plt.scatter(epochs, eff_train_loss, label="Train Loss")
plt.scatter(epochs, eff_val_loss, label="Validation Loss")
plt.plot(epochs, eff_train_loss)
plt.plot(epochs, eff_val_loss)
plt.title("EfficientNetB0 Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Accuracy
res_train_acc = [0.6846,0.8164,0.8544,0.8668,0.8757,0.8885,0.8952,0.8960,0.9015,0.9060,
                 0.9170,0.9111,0.9123,0.9240,0.9223,0.9202,0.9267,0.9316,0.9284,0.9298,
                 0.9307,0.9342,0.9375,0.9391,0.9414]

res_val_acc = [0.8227,0.8478,0.8600,0.8653,0.8744,0.8820,0.8782,0.8836,0.8942,0.8980,
               0.9049,0.9026,0.9064,0.9148,0.9178,0.9132,0.9186,0.9087,0.9216,0.9231,
               0.9239,0.9239,0.9224,0.9247,0.9254]

# Loss
res_train_loss = [0.8136,0.5001,0.4037,0.3653,0.3525,0.3088,0.2968,0.2947,0.2672,0.2648,
                  0.2471,0.2416,0.2417,0.2191,0.2175,0.2141,0.2090,0.2021,0.2007,0.1971,
                  0.1872,0.1835,0.1755,0.1760,0.1726]

res_val_loss = [0.4776,0.4058,0.3754,0.3457,0.3171,0.2970,0.2950,0.2927,0.2567,0.2555,
                0.2428,0.2463,0.2366,0.2230,0.2145,0.2129,0.2055,0.2197,0.1934,0.1882,
                0.1828,0.1867,0.1928,0.1772,0.1729]

# Accuracy Graph
plt.figure()
plt.scatter(epochs, res_train_acc, label="Train Accuracy")
plt.scatter(epochs, res_val_acc, label="Validation Accuracy")
plt.plot(epochs, res_train_acc)
plt.plot(epochs, res_val_acc)
plt.title("ResNet50 Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Loss Graph
plt.figure()
plt.scatter(epochs, res_train_loss, label="Train Loss")
plt.scatter(epochs, res_val_loss, label="Validation Loss")
plt.plot(epochs, res_train_loss)
plt.plot(epochs, res_val_loss)
plt.title("ResNet50 Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Accuracy
den_train_acc = [0.5887,0.7728,0.8063,0.8278,0.8493,0.8497,0.8649,0.8672,0.8733,0.8862,
                 0.8854,0.8798,0.8876,0.8941,0.8903,0.8939,0.8976,0.8967,0.9013,0.9041,
                 0.9029,0.9097,0.9046,0.9130,0.9135]

den_val_acc = [0.7747,0.7953,0.8242,0.8250,0.8311,0.8333,0.8432,0.8409,0.8356,0.8554,
               0.8394,0.8630,0.8600,0.8623,0.8699,0.8714,0.8721,0.8729,0.8721,0.8775,
               0.8820,0.8752,0.8836,0.8881,0.8874]

# Loss
den_train_loss = [1.0237,0.6334,0.5280,0.4698,0.4340,0.4092,0.3915,0.3733,0.3519,0.3398,
                  0.3302,0.3258,0.3191,0.2924,0.3063,0.2950,0.2888,0.2844,0.2706,0.2688,
                  0.2635,0.2559,0.2531,0.2432,0.2480]

den_val_loss = [0.6280,0.5250,0.4697,0.4570,0.4305,0.4168,0.3879,0.3813,0.3951,0.3599,
                0.3733,0.3388,0.3283,0.3254,0.3167,0.3097,0.2937,0.2914,0.3007,0.2948,
                0.2845,0.2934,0.2738,0.2683,0.2666]

# Accuracy Graph
plt.figure()
plt.scatter(epochs, den_train_acc, label="Train Accuracy")
plt.scatter(epochs, den_val_acc, label="Validation Accuracy")
plt.plot(epochs, den_train_acc)
plt.plot(epochs, den_val_acc)
plt.title("DenseNet121 Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Loss Graph
plt.figure()
plt.scatter(epochs, den_train_loss, label="Train Loss")
plt.scatter(epochs, den_val_loss, label="Validation Loss")
plt.plot(epochs, den_train_loss)
plt.plot(epochs, den_val_loss)
plt.title("DenseNet121 Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
